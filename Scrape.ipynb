# %%
import requests
import pandas as pd 
from datetime import datetime
import json

# %% [markdown]
# # Scrape raw data

# %%
url = "https://api.climateview.global/boards/Boards/ec2d0cdf-e70e-43fb-85cb-ed6b31ee1e09/published/v3"
r = requests.get(url)

# %% [markdown]
# # Store copy of raw data

# %%
json_data = r.json()

today = datetime.now().strftime('%Y-%m-%d')

outfile = f"data/raw/{today}.json"
with open(outfile, "w") as f:
    json.dump(json_data, f, indent=2)
    print(f"=> {outfile}")
# Out:
# => data/raw/2023-03-26.json

# %% [markdown]
# # Parse key data to csv

# %%
def get_values(d):
    """Parse non-nested values (no dicts or lists)"""
    values = {}
    for k, v in d.items():
        if isinstance(v, list) or isinstance(v, dict):
            continue
        values[k] = v
    return values


nodes = []
for node_id, node_data in json_data["content"]["entityData"]["nodes"].items():
    node = {
        "id": node_id,
        "title": node_data["title"],
    }
    # parse data
    node.update(get_values(node_data["nodeProperties"]))

    if "customTargetModelData" in node_data["nodeProperties"]:
        # parse more data
        node.update(get_values(node_data["nodeProperties"]["customTargetModelData"]))
        
        # get timeserie data from charts
        chart_data = node_data["nodeProperties"]["customTargetModelData"]["chartData"]
        for k, v in chart_data.items():
            node[k] = json.dumps(v)
        
        nodes.append(node)

outfile = f"data/parsed/{today}.csv"
df_nodes = pd.DataFrame(nodes).set_index("id")
df_nodes.to_csv(outfile)
print(f"=> {outfile}")
# Out:
# => data/parsed/2023-03-26.csv

# %%
d = node_data["nodeProperties"]["customTargetModelData"]["chartData"]

def interpolate(ts_dict):
    s = pd.Series(ts_dict)
    s.index = s.index.astype(int)
    y_min = s.index.min()
    y_max = s.index.max()
    s = s.reindex(range(y_min, y_max + 1))
    return s.interpolate().to_dict()


# 'carbonAbatement'
#    s_target.index = s_target.index.astype(int)
#    years = list(range(s_target.index[0], s_target.index[-1] + 1))
#    s_target = s_target.reindex(years).interpolate()


to_list(interpolate(d['carbonAbatement']))
# Out:
# [(2010, 0.0),
#  (2011, 0.0),
#  (2012, 0.0),
#  (2013, 0.0),
#  (2014, 0.0),
#  (2015, 0.0),
#  (2016, 0.0),
#  (2017, 0.0),
#  (2018, 0.0),
#  (2019, 0.0),
#  (2020, 0.0),
#  (2021, 0.0),
#  (2022, 0.0),
#  (2023, 0.0),
#  (2024, 0.0),
#  (2025, 3.0),
#  (2026, 3.0),
#  (2027, 3.0),
#  (2028, 3.0),
#  (2029, 3.0),
#  (2030, 4.616),
#  (2031, 4.6358),
#  (2032, 4.6556),
#  (2033, 4.6754),
#  (2034, 4.6952),
#  (2035, 4.715),
#  (2036, 4.7348),
#  (2037, 4.7546),
#  (2038, 4.7744),
#  (2039, 4.7942),
#  (2040, 4.814),
#  (2041, 4.8338),
#  (2042, 4.8536),
#  (2043, 4.8734),
#  (2044, 4.8932),
#  (2045, 4.913)]

# %%
d["target"]
# Out:
# {'2010': 0, '2024': 0, '2025': 65, '2029': 65, '2030': 100, '2045': 100}

# %%
pd.Series({2020: 1, 2021: None, 2023: 8}).reindex([2020,2021, 2022, 2023]).interpolate()
# Out:
# 2020    1.000000
# 2021    3.333333
# 2022    5.666667
# 2023    8.000000
# dtype: float64

# %%
# parse indicator data
indicators = []
for d in json_data["content"]["boardData"]["indicators"]:
    item = {
        "id": d["id"],
        "title": d["title"],
        **d["indicatorProperties"],
    }
    indicators.append(item)

df_ind = pd.DataFrame(indicators).set_index("id")

# Harmonisera enhet
# En del indikatorer är ton 
df_ind["co2ePotential"] = df_ind["co2ePotential"] * df_ind["co2eUnit"].apply(lambda x: {"Mton": 1, "ton": 1 / 10e6}.get(x))


def interpolate_potential_curve(list_of_dicts):
    df_ts = pd.DataFrame(list_of_dicts).set_index("date")
    df_ts.index = pd.to_datetime(df_ts.index)
    if "value" not in df_ts.columns:
        df_ts["value"] = None
        df_ts["co2e"] = None
    else:
        df_ts["value"] = df_ts["value"].interpolate()
        df_ts["co2e"] = df_ts["co2e"].interpolate()

    return df_ts

# Data för varje år
df_ind["potentialCurve"] = df_ind["potentialCurve"].apply(interpolate_potential_curve)



def get_outcome_data(l):
    s = pd.DataFrame(l).set_index("date")["values"]
    s.index = pd.to_datetime(s.index)
    # [ 2.2 ] = >2.2
    s = s.str[0].dropna()

    if len(s) > 0:
        resp = {
            "LatestValue": s.iloc[-1],
            "LatestTimepoint": s.index[-1],
        }
        if len(s) > 1:
            resp["PrevValue"] = s.iloc[-2]
            resp["PrevTimepoint"] = s.index[-2]
    else:
        resp = {}


    return pd.Series(resp)

# Hämta senast observerade data (samt föregående)
_df_latest_outcome = df_ind["outcome"].apply(get_outcome_data).add_prefix("outcome")
df_ind = df_ind.join(_df_latest_outcome)

def get_latest_potential(row):
    latest_tp = row["outcomeLatestTimepoint"]
    if pd.isnull(latest_tp):
        return None
    else:
        return pd.Series({
            "potentialLatestValue": row["potentialCurve"].loc[latest_tp, "value"],
            "potentialLatestCO2e": row["potentialCurve"].loc[latest_tp, "co2e"],
        })

# Hämta det värde i "potentialValue" som korresponderar till senaste observerade data
_df_latest_potential =  df_ind.apply(get_latest_potential, axis=1)

df_ind = df_ind.join(_df_latest_potential)

df_ind["outcomeVsPotential"] = df_ind["outcomeLatestValue"] - df_ind["potentialLatestValue"]

df_ind.iloc[1].head(30)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_118760/2313132770.py in <module>
#       1 # parse indicator data
#       2 indicators = []
# ----> 3 for d in json_data["content"]["boardData"]["indicators"]:
#       4     item = {
#       5         "id": d["id"],
#
# KeyError: 'indicators'

# %%
# Out:
# title                   Andel elanvändning
# outcomeLatestValue                   26.76
# potentialLatestValue                 30.27
# outcomeVsPotential                   -3.51
# goalValue                              NaN
# diff                                 -3928
# co2ePotential                        0.117
# Name: 37, dtype: object

# %%
base_url = "https://app.climateview.global/public/board/ec2d0cdf-e70e-43fb-85cb-ed6b31ee1e09?id="
df["url"] = base_url + df["id"]

# %%
# parse indicator data
nodes = []
for d in json_data["content"]["boardData"]["nodes"]:
    item = {
        "id": d["id"],
        "title": d["title"],
        **d["nodeProperties"],
    }
    if len(d["indicators"]) > 0:
        d["indicator"] = d["indicators"][0]
        assert len(d["indicators"]) == 1

    nodes.append(item)

df_nodes = pd.DataFrame(nodes).set_index("id")


df_nodes.loc["206f6b8d-c66c-477f-bed1-0204ccfad522"].customTargetModelData

def parse_model_data(json_blob):
    if pd.isna(json_blob):
        return pd.Series({})
    s_outcome = pd.Series(json_blob["chartData"]["outcome"])
    s_outcome.index = s_outcome.index.astype(int)

    if len(s_outcome) == 0:
        return pd.Series({})
    
    

    latest_tp = s_outcome.index.max()

    # interpolera target-serien för att få data för alla år
    s_target = pd.Series(json_blob["chartData"]["target"])
    s_target.index = s_target.index.astype(int)
    years = list(range(s_target.index[0], s_target.index[-1] + 1))
    s_target = s_target.reindex(years).interpolate()

    
    resp = {
        "latestTimepoint": latest_tp,
        "latestOutcome": s_outcome[latest_tp],
        "latestTarget": s_target.get(latest_tp),
    }
    if resp["latestTarget"]:
        resp["diff"] = s_outcome[latest_tp] - s_target[latest_tp]
        resp["diffPct"] = s_outcome[latest_tp] / s_target[latest_tp] - 1
    return pd.Series(resp)

df_outcome_vs_target = df_nodes.customTargetModelData.apply(parse_model_data)

#_df[_df.latestTimepoint.notna()].sort_values("diffPct")

df_nodes = pd.concat([
    df_nodes.drop("diff", axis=1),
    df_outcome_vs_target,
], axis=1)
df_nodes["outcomeCategory"] = df_nodes["diffPct"].apply(lambda x: "good" if x > 0 else "bad")
df_nodes["diffPctWeighted"] = df_nodes["co2e"] * df_nodes["diffPct"]

has_data = df_nodes.diffPct.notna()
main_cols = ["title", "co2e", "latestOutcome", "latestTarget", "diffPct"]
df_nodes[has_data][main_cols].to_csv("~/Downloads/panorma-nodes-outcome-vs-target-3.csv")
df_nodes[has_data].sort_values("diffPctWeighted")
# Out:
# /tmp/ipykernel_45146/849512500.py:22: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series({})
# /tmp/ipykernel_45146/849512500.py:23: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s_outcome = pd.Series(json_blob["chartData"]["outcome"])
# /tmp/ipykernel_45146/849512500.py:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series({})
#                                                                                  title  \
# id
# 7628b744-d658-4ca8-91ce-6f105d81dd45                       Biobränsle istället för kol
# 1c910ad7-5124-4d9f-9758-a9a0a19e7f37         Biobränsle för cement och mineralindustri
# b61ae7e0-6b0b-4ecd-88eb-e853f292f714               Minskad användning av lösningsmedel
# 8b301e8b-5b22-4124-97d6-e7d95b6f741e                                 Förnybara råvaror
# ab98a4aa-a42c-4375-a758-625e714c84aa                      Elektrifiering av produktion
# ebb72100-0b8d-4117-b652-a7b2593c179d                      Biodrivmedel inrikes sjöfart
# 0328c7f3-a938-42c4-a62c-b238180ddd27                        Fossilfri vätgasproduktion
# 8f3e69ba-6ffd-46ca-a493-b7b627fe0481  Från betong/stål till trästomme i flerbostadshus
# cc3d3604-ff91-400b-937d-20aec0fd28bc                        Ökad andel kollektivtrafik
# 40740dea-2ece-447a-995a-67ff093828c7                        Överflyttning till järnväg
# 24d0ebb5-d3cc-4822-a447-315cf5162495                                     Inerta anoder
# e824f69d-f682-490b-8155-1dce864ddc11                             Ökad plaståtervinning
# eb059e10-02b6-4f18-a7ad-bab08d0e6351                     Biogas i kommersiella lokaler
# 49c7084e-b791-4f0d-9b31-36b004359467                 Elektrifiering av inrikes sjöfart
# c0520dec-8ba7-4f16-996d-f07f4b66cbe3                 Elektrifiering av tunga lastbilar
# c185ddbb-550c-4d9b-b243-fdf045f10cc0     Avfallsförbränning som ersatts med spillvärme
# 95c0c013-7789-44eb-bc48-9daf778b13f4  ...
# 28105d6c-e7e0-4f15-a6fc-a2f8893237ac  ...
# c708f353-fd8b-4748-9437-6daf0ba135b4  ...
# c90b0061-9323-4080-a788-6866776cdd53  ...
# 206f6b8d-c66c-477f-bed1-0204ccfad522  ...
#
#                                                                    transitionTargetData  \
# id
# 7628b744-d658-4ca8-91ce-6f105d81dd45                                                NaN
# 1c910ad7-5124-4d9f-9758-a9a0a19e7f37                                                NaN
# b61ae7e0-6b0b-4ecd-88eb-e853f292f714                                                NaN
# 8b301e8b-5b22-4124-97d6-e7d95b6f741e                                                NaN
# ab98a4aa-a42c-4375-a758-625e714c84aa                                                NaN
# ebb72100-0b8d-4117-b652-a7b2593c179d  {'transitionProperties': {'targetLevel': 0.25,...
# 0328c7f3-a938-42c4-a62c-b238180ddd27                                                NaN
# 8f3e69ba-6ffd-46ca-a493-b7b627fe0481  {'transitionProperties': {'targetLevel': 0.25,...
# cc3d3604-ff91-400b-937d-20aec0fd28bc                                                NaN
# 40740dea-2ece-447a-995a-67ff093828c7  {'transitionProperties': {'targetLevel': 0.25,...
# 24d0ebb5-d3cc-4822-a447-315cf5162495                                                NaN
# e824f69d-f682-490b-8155-1dce864ddc11                                                NaN
# eb059e10-02b6-4f18-a7ad-bab08d0e6351  {'transitionProperties': {'targetLevel': 0.25,...
# 49c7084e-b791-4f0d-9b31-36b004359467  {'transitionProperties': {'targetLevel': 0.25,...
# c0520dec-8ba7-4f16-996d-f07f4b66cbe3  {'transitionProperties': {'targetLevel': 0.25,...
# c185ddbb-550c-4d9b-b243-fdf045f10cc0  {'transitionProperties': {'targetLevel': 0.25,...
# b251af68-c00f-409e-ae4c-2e9964af258c                                                NaN
# 8879e250-acf0-4418-86e8-0c4afecaa622  {'transitionProperties': {'targetLevel': 0.25,...
# 6b82e094-8caa-41a5-9f48-2586242a0784  {'transitionProperties': {'targetLevel': 0.25,...
# f4c01ab7-ee6a-4a03-8f85-1597c57a0ee4                                                NaN
# 4fd1bae4-5cca-4c29-a31d-f399fb99ba05                                                NaN
# ca2374a9-b54b-44a9-9695-3344cc257b30  {'transitionProperties': {'targetLevel': 0.25,...
# 467c2fa7-88b2-4293-a8f1-995abc821c8f  {'transitionProperties': {'targetLevel': 0.25,...
# 1d415104-3947-40e6-bd96-c3d0def3466e  {'transitionProperties': {'targetLevel': 0.25,...
# 924d768d-8447-41cf-a28d-dac49bc23946                                                NaN
# e5e6a0c8-1c61-4e87-9528-440ba51e4b68  {'transitionProperties': {'targetLevel': 0.25,...
# 6373d1e3-a996-48ac-a840-e6054ef75ca2  {'transitionProperties': {'targetLevel': 0.25,...
# 2bc6c9c3-6a2e-4b51-b25a-95cb4a49be4b                                                NaN
# 09eabf4b-ad4a-417d-9994-fa538b88184f  {'transitionProperties': {'targetLevel': 0.25,...
# 14ae8d72-a905-44e1-b8e3-f056b6900ba5  {'transitionProperties': {'targetLevel': 0.25,...
# 41bdd6f8-51cd-46c0-9b7f-6ed673897afd  {'transitionProperties': {'targetLevel': 0.25,...
# c69104a5-5e6a-4f24-8cd6-90dd42a3d5b5  {'transitionProperties': {'targetLevel': 0.25,...
# aa1fd846-9afa-4bb1-bbd9-aecabcb7196c  {'transitionProperties': {'targetLevel': 0.25,...
# 12a60298-5958-4463-96ab-6b9d796375e5  {'transitionProperties': {'targetLevel': 0.25,...
# f5f3705a-2bad-40fa-ae76-4ca172fedef5                                                NaN
# 7116d4de-994d-4a5f-bf9d-82a25a36ecb2                                                NaN
# e24f65a4-273f-40f4-9191-fd892dc0a28d  {'transitionProperties': {'targetLevel': 0.4, ...
# 18d939a9-dd4f-48f9-b2f4-b5f81be5bf5b                                                NaN
# 4727ff43-b1c4-4ed6-9aa5-7b8cebd12888  {'transitionProperties': {'targetLevel': 0.25,...
# a1cd0940-a539-4820-8e0a-88b62fc75f7b                                                NaN
# 48a8e3a4-80b5-4108-9ff2-caf731b273df                                                NaN
# 2dd04c9a-fe77-4f84-93e6-5e8566f79ee5  {'transitionProperties': {'targetLevel': 0.25,...
# 5f5e13d7-25cf-4707-829d-6ae1970b4eb8                                                NaN
# 95c0c013-7789-44eb-bc48-9daf778b13f4  {'transitionProperties': {'targetLevel': 1, 'u...
# 28105d6c-e7e0-4f15-a6fc-a2f8893237ac                                                NaN
# c708f353-fd8b-4748-9437-6daf0ba135b4                                                NaN
# c90b0061-9323-4080-a788-6866776cdd53  {'transitionProperties': {'targetLevel': 0.25,...
# 206f6b8d-c66c-477f-bed1-0204ccfad522  {'transitionProperties': {'targetLevel': 0.25,...
#
#                                       firebaseId achivableLater  \
# id
# 7628b744-d658-4ca8-91ce-6f105d81dd45         NaN            NaN
# 1c910ad7-5124-4d9f-9758-a9a0a19e7f37         NaN            NaN
# b61ae7e0-6b0b-4ecd-88eb-e853f292f714         NaN            NaN
# 8b301e8b-5b22-4124-97d6-e7d95b6f741e         NaN            NaN
# ab98a4aa-a42c-4375-a758-625e714c84aa         NaN            NaN
# ebb72100-0b8d-4117-b652-a7b2593c179d         NaN            NaN
# 0328c7f3-a938-42c4-a62c-b238180ddd27         NaN            NaN
# 8f3e69ba-6ffd-46ca-a493-b7b627fe0481         NaN            NaN
# cc3d3604-ff91-400b-937d-20aec0fd28bc         NaN            NaN
# 40740dea-2ece-447a-995a-67ff093828c7         NaN            NaN
# 24d0ebb5-d3cc-4822-a447-315cf5162495         NaN            NaN
# e824f69d-f682-490b-8155-1dce864ddc11         NaN            NaN
# eb059e10-02b6-4f18-a7ad-bab08d0e6351         NaN            NaN
# 49c7084e-b791-4f0d-9b31-36b004359467         NaN            NaN
# c0520dec-8ba7-4f16-996d-f07f4b66cbe3         NaN            NaN
# c185ddbb-550c-4d9b-b243-fdf045f10cc0         NaN            NaN
# b251af68-c00f-409e-ae4c-2e9964af258c         NaN            NaN
# 8879e250-acf0-4418-86e8-0c4afecaa622         NaN            NaN
# 6b82e094-8caa-41a5-9f48-2586242a0784         NaN            NaN
# f4c01ab7-ee6a-4a03-8f85-1597c57a0ee4         NaN            NaN
# 4fd1bae4-5cca-4c29-a31d-f399fb99ba05         NaN            NaN
# ca2374a9-b54b-44a9-9695-3344cc257b30         NaN            NaN
# 467c2fa7-88b2-4293-a8f1-995abc821c8f         NaN            NaN
# 1d415104-3947-40e6-bd96-c3d0def3466e         NaN            NaN
# 924d768d-8447-41cf-a28d-dac49bc23946         NaN            NaN
# e5e6a0c8-1c61-4e87-9528-440ba51e4b68         NaN            NaN
# 6373d1e3-a996-48ac-a840-e6054ef75ca2         NaN            NaN
# 2bc6c9c3-6a2e-4b51-b25a-95cb4a49be4b         NaN            NaN
# 09eabf4b-ad4a-417d-9994-fa538b88184f         NaN            NaN
# 14ae8d72-a905-44e1-b8e3-f056b6900ba5         NaN            NaN
# 41bdd6f8-51cd-46c0-9b7f-6ed673897afd         NaN            NaN
# c69104a5-5e6a-4f24-8cd6-90dd42a3d5b5         NaN            NaN
# aa1fd846-9afa-4bb1-bbd9-aecabcb7196c         NaN            NaN
# 12a60298-5958-4463-96ab-6b9d796375e5         NaN            NaN
# f5f3705a-2bad-40fa-ae76-4ca172fedef5         NaN            NaN
# 7116d4de-994d-4a5f-bf9d-82a25a36ecb2         NaN            NaN
# e24f65a4-273f-40f4-9191-fd892dc0a28d         NaN            NaN
# 18d939a9-dd4f-48f9-b2f4-b5f81be5bf5b         NaN            NaN
# 4727ff43-b1c4-4ed6-9aa5-7b8cebd12888         NaN            NaN
# a1cd0940-a539-4820-8e0a-88b62fc75f7b         NaN            NaN
# 48a8e3a4-80b5-4108-9ff2-caf731b273df         NaN            NaN
# 2dd04c9a-fe77-4f84-93e6-5e8566f79ee5         NaN            NaN
# 5f5e13d7-25cf-4707-829d-6ae1970b4eb8         NaN            NaN
# 95c0c013-7789-44eb-bc48-9daf778b13f4         NaN            NaN
# 28105d6c-e7e0-4f15-a6fc-a2f8893237ac         NaN            NaN
# c708f353-fd8b-4748-9437-6daf0ba135b4         NaN            NaN
# c90b0061-9323-4080-a788-6866776cdd53         NaN            NaN
# 206f6b8d-c66c-477f-bed1-0204ccfad522         NaN            NaN
#
#                                      latestTimepoint latestOutcome  \
# id
# 7628b744-d658-4ca8-91ce-6f105d81dd45          2020.0       0.00000
# 1c910ad7-5124-4d9f-9758-a9a0a19e7f37          2019.0       5.78216
# b61ae7e0-6b0b-4ecd-88eb-e853f292f714          2019.0       3.00000
# 8b301e8b-5b22-4124-97d6-e7d95b6f741e          2021.0       2.50000
# ab98a4aa-a42c-4375-a758-625e714c84aa          2018.0       0.00000
# ebb72100-0b8d-4117-b652-a7b2593c179d          2020.0       5.10000
# 0328c7f3-a938-42c4-a62c-b238180ddd27          2021.0       0.00000
# 8f3e69ba-6ffd-46ca-a493-b7b627fe0481          2020.0    4110.00000
# cc3d3604-ff91-400b-937d-20aec0fd28bc          2021.0       8.47000
# 40740dea-2ece-447a-995a-67ff093828c7          2021.0       6.54000
# 24d0ebb5-d3cc-4822-a447-315cf5162495          2022.0       0.00000
# e824f69d-f682-490b-8155-1dce864ddc11          2020.0   46400.00000
# eb059e10-02b6-4f18-a7ad-bab08d0e6351          2019.0     115.00000
# 49c7084e-b791-4f0d-9b31-36b004359467          2020.0       0.00000
# c0520dec-8ba7-4f16-996d-f07f4b66cbe3          2021.0     413.00000
# c185ddbb-550c-4d9b-b243-fdf045f10cc0          2019.0    4566.00000
# aa1fd846-9afa-4bb1-bbd9-aecabcb7196c             good         0.007036
# 12a60298-5958-4463-96ab-6b9d796375e5             good         0.007171
# f5f3705a-2bad-40fa-ae76-4ca172fedef5             good         0.013543
# 7116d4de-994d-4a5f-bf9d-82a25a36ecb2             good         0.014796
# e24f65a4-273f-40f4-9191-fd892dc0a28d             good         0.016911
# 18d939a9-dd4f-48f9-b2f4-b5f81be5bf5b             good         0.036503
# 4727ff43-b1c4-4ed6-9aa5-7b8cebd12888             good         0.049016
# a1cd0940-a539-4820-8e0a-88b62fc75f7b             good         0.051586
# 48a8e3a4-80b5-4108-9ff2-caf731b273df             good         0.058815
# 2dd04c9a-fe77-4f84-93e6-5e8566f79ee5             good         0.084318
# 5f5e13d7-25cf-4707-829d-6ae1970b4eb8             good         0.138028
# 95c0c013-7789-44eb-bc48-9daf778b13f4             good         0.280815
# 28105d6c-e7e0-4f15-a6fc-a2f8893237ac             good         0.280815
# c708f353-fd8b-4748-9437-6daf0ba135b4             good         0.401390
# c90b0061-9323-4080-a788-6866776cdd53             good         0.579213
# 206f6b8d-c66c-477f-bed1-0204ccfad522             good         0.897499
#
# [48 rows x 31 columns]

# %%
indicator_cols = ["title", "outcomeLatestValue", "potentialLatestValue", "outcomeVsPotential", "goalValue", "diff", "co2ePotential"]
df_ind[indicator_cols].columns.map(lambda x: "Indicator" + x.title())

["title", ]
df_nodes.columns
# Out:
# Index(['title', 'icon', 'type', 'imgURL', 'thumbnailURL', 'description',
#        'co2e', 'data', 'diagramHeader', 'extendedDescription',
#        'achievableLater', 'notAchievable', 'groupColour',
#        'historicalEmissionData', 'modelType', 'customTargetModelData',
#        'transitionTargetDescription', 'transitionTargetSummary', 'status',
#        'transitionTarget', 'transitionElement', 'transitionTargetData',
#        'firebaseId', 'achivableLater', 'latestTimepoint', 'latestOutcome',
#        'latestTarget', 'diff', 'diffPct', 'outcomeCategory',
#        'diffPctWeighted'],
#       dtype='object')

# %%
df_nodes.loc["40740dea-2ece-447a-995a-67ff093828c7"]
# Out:
# title                                                 Överflyttning till järnväg
# icon                           /assets/images/transition-elements-icons/trans...
# type                                                                           5
# imgURL
# thumbnailURL
# description
# co2e                                                                       0.607
# data                                                                          []
# diagramHeader                                           Möjlig utsläppsminskning
# extendedDescription            {'data': {'texts': [{'title': 'Åka tåg'}], 'im...
# achievableLater                                                            False
# notAchievable                                                              False
# groupColour                                                                  NaN
# historicalEmissionData                                                       NaN
# modelType                                                                 custom
# customTargetModelData          {'chartData': {'carbonAbatement': {'2010': 0, ...
# transitionTargetDescription    <p>Transporter på järnväg ger låga utsläpp av ...
# transitionTargetSummary
# status                                                                       5.0
# transitionTarget                                                             3.0
# transitionElement                                   transfer_from_car_to_railway
# transitionTargetData           {'transitionProperties': {'targetLevel': 0.25,...
# firebaseId                                                                   NaN
# achivableLater                                                               NaN
# latestTimepoint                                                           2021.0
# latestOutcome                                                               6.54
# latestTarget                                                              9.8215
# diff                                                                     -3.2815
# diffPct                                                                -0.334114
# outcomeCategory                                                              bad
# diffPctWeighted                                                        -0.202807
# Name: 40740dea-2ece-447a-995a-67ff093828c7, dtype: object
